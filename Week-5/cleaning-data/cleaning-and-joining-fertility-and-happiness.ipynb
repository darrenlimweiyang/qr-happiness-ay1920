# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df1 = pd.read_csv("2019-world-happiness.csv")

# %%
df2 = pd.read_csv("world-fertility-data-test.csv")

# %%
df1.head(2)
# Out:
#   Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590             7.16869        0.450662
# 1  Afghanistan  2009     4.401778             7.33379        0.552308
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.799999                      0.718114    0.177889
# 1                         51.200001                      0.678896    0.200178
#
#    Perceptions of corruption  Positive affect  ...  \
# 0                   0.881686         0.517637  ...
# 1                   0.850035         0.583926  ...
#
#    GINI index (World Bank estimate)  \
# 0                               NaN
# 1                               NaN
#
#    GINI index (World Bank estimate), average 2000-16  \
# 0                                                NaN
# 1                                                NaN
#
#    gini of household income reported in Gallup, by wp5-year  \
# ...

# %%
df2.head(2)
# Out:
#   Country Name Country Code                            Indicator Name  \
# 0        Aruba          ABW  Fertility rate, total (births per woman)
# 1  Afghanistan          AFG  Fertility rate, total (births per woman)
#
#    Indicator Code  1960   1961   1962   1963   1964   1965  ...   2010   2011  \
# 0  SP.DYN.TFRT.IN  4.82  4.655  4.471  4.271  4.059  3.842  ...  1.768  1.779
# 1  SP.DYN.TFRT.IN  7.45  7.450  7.450  7.450  7.450  7.450  ...  5.977  5.770
#
#     2012   2013   2014   2015   2016   2017  2018  2019
# 0  1.795  1.813  1.834  1.854  1.872  1.886   NaN   NaN
# 1  5.562  5.359  5.163  4.976  4.800  4.633   NaN   NaN
#
# [2 rows x 64 columns]

# %%
df2_melted = pd.melt(df2, ['Country Name',
                          'Country Code',
                          'Indicator Name',
                          'Indicator Code'], ['1960',
 '1961',
 '1962',
 '1963',
 '1964',
 '1965',
 '1966',
 '1967',
 '1968',
 '1969',
 '1970',
 '1971',
 '1972',
 '1973',
 '1974',
 '1975',
 '1976',
 '1977',
 '1978',
 '1979',
 '1980',
 '1981',
 '1982',
 '1983',
 '1984',
 '1985',
 '1986',
 '1987',
 '1988',
 '1989',
 '1990',
 '1991',
 '1992',
 '1993',
 '1994',
 '1995',
 '1996',
 '1997',
 '1998',
 '1999',
 '2000',
 '2001',
 '2002',
 '2003',
 '2004',
 '2005',
 '2006',
 '2007',
 '2008',
 '2009',
 '2010',
 '2011',
 '2012',
 '2013',
 '2014',
 '2015',
 '2016',
 '2017',
 '2018',
 '2019'])

# %%
list_of_cty_df2 = df2['Country Name'].tolist()

# %%
list_of_cty_df1 = df1['Country name'].unique().tolist()

# %%
list_in_df1_not_df2 = []
for x in list_of_cty_df1:
    if x not in list_of_cty_df2:
        list_in_df1_not_df2 += [x]

# %%
list_in_df1_not_df2
# Out:
# ['Congo (Brazzaville)',
#  'Congo (Kinshasa)',
#  'Egypt',
#  'Gambia',
#  'Hong Kong S.A.R. of China',
#  'Iran',
#  'Ivory Coast',
#  'Kyrgyzstan',
#  'Laos',
#  'Macedonia',
#  'North Cyprus',
#  'Palestinian Territories',
#  'Russia',
#  'Slovakia',
#  'Somaliland region',
#  'South Korea',
#  'Swaziland',
#  'Syria',
#  'Taiwan Province of China',
#  'Venezuela',
#  'Yemen']

# %%
list_in_df2_not_df1 = []
for x in list_of_cty_df2:
    if x not in list_of_cty_df1:
        list_in_df2_not_df1 += [x]

# %%
list_in_df2_not_df1
# Out:
# ['Aruba',
#  'Andorra',
#  'Arab World',
#  'American Samoa',
#  'Antigua and Barbuda',
#  'Bahamas, The',
#  'Bermuda',
#  'Barbados',
#  'Brunei Darussalam',
#  'Central Europe and the Baltics',
#  'Channel Islands',
#  "Cote d'Ivoire",
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Cabo Verde',
#  'Caribbean small states',
#  'Curacao',
#  'Cayman Islands',
#  'Dominica',
#  'East Asia & Pacific (excluding high income)',
#  'Early-demographic dividend',
#  'East Asia & Pacific',
#  'Europe & Central Asia (excluding high income)',
#  'Europe & Central Asia',
#  'Egypt, Arab Rep.',
#  'Euro area',
#  'Eritrea',
#  'European Union',
#  'Fragile and conflict affected situations',
#  'Fiji',
#  'Faroe Islands',
#  'Micronesia, Fed. Sts.',
#  'Gibraltar',
#  'Gambia, The',
#  'Guinea-Bissau',
#  'Equatorial Guinea',
#  'Grenada',
#  'Greenland',
#  'Guam',
#  'High income',
#  'Hong Kong SAR, China',
#  'Heavily indebted poor countries (HIPC)',
#  'IBRD only',
#  'IDA & IBRD total',
# ...

# %% [markdown]
# # After manual Edits

# %%
happiness_df = df1

# %%
fertility_df = pd.read_csv("world-fertility-data.csv")

# %% [markdown]
# ## Pivoting in python!

# %%
fertility_melted = pd.melt(fertility_df, ['Country Name',
                          'Country Code',
                          'Indicator Name',
                          'Indicator Code'], ['1960',
 '1961',
 '1962',
 '1963',
 '1964',
 '1965',
 '1966',
 '1967',
 '1968',
 '1969',
 '1970',
 '1971',
 '1972',
 '1973',
 '1974',
 '1975',
 '1976',
 '1977',
 '1978',
 '1979',
 '1980',
 '1981',
 '1982',
 '1983',
 '1984',
 '1985',
 '1986',
 '1987',
 '1988',
 '1989',
 '1990',
 '1991',
 '1992',
 '1993',
 '1994',
 '1995',
 '1996',
 '1997',
 '1998',
 '1999',
 '2000',
 '2001',
 '2002',
 '2003',
 '2004',
 '2005',
 '2006',
 '2007',
 '2008',
 '2009',
 '2010',
 '2011',
 '2012',
 '2013',
 '2014',
 '2015',
 '2016',
 '2017',
 '2018',
 '2019'])

# %%
fertility_melted.rename(columns={"variable":"Year", "value":"Fertility Score"}
                       ,inplace=True)

# %%
happiness_df.rename(columns={"Country name":"Country Name"},
                   inplace=True)

# %%
type(fertility_melted['Year'].iloc[0])
# Out:
# str

# %%
happiness_df['Year'] = happiness_df['Year'].apply(lambda x: str(x))

# %%
combined_df = happiness_df.merge(fertility_melted,
                                how="left",
                                on=["Country Name", "Year"])

# %%
combined_df.to_csv("Fertility_and_Happiness.csv")
